# %% [markdown]
# ### GPyTorch reprex
#
# This notebook makes a minimal reproducible example for running a GP model on elevation data. We do this in the following steps:
#
#  - `torch.DataLoader` to pull a chunk from the zarr dataset
#  - Transformation function to turn the chunk into a `torch.Tensor`
#  - Feed the `Tensor` into a GPyTorch model

# %% [markdown]
# ### DataLoader
#
# Adapted from [here](https://discuss.pytorch.org/t/dataloader-parallelization-synchronization-with-zarr-xarray-dask/176149).

# %%
# %pip install torch tqdm gpytorch
# Out:
# Collecting torch
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.10/site-packages (4.64.1)
# Collecting gpytorch
#   Downloading gpytorch-1.11-py3-none-any.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 6.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions in /srv/conda/envs/notebook/lib/python3.10/site-packages (from torch) (4.6.3)
# Collecting nvidia-cuda-runtime-cu12==12.1.105
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 13.4 MB/s eta 0:00:0000:01
# Collecting nvidia-cusolver-cu12==11.4.5.107
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 15.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.1.105
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 1.9 MB/s eta 0:00:00ta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 39.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.2.106
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 26.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.1.3.1
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu12==12.1.105
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 42.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: sympy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from torch) (1.11.1)
# Collecting nvidia-nccl-cu12==2.18.1
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.4 MB/s eta 0:00:0000:0100:01
# Collecting triton==2.1.0
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 20.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: fsspec in /srv/conda/envs/notebook/lib/python3.10/site-packages (from torch) (2023.6.0)
# Requirement already satisfied: networkx in /srv/conda/envs/notebook/lib/python3.10/site-packages (from torch) (2.8.8)
# Collecting nvidia-cufft-cu12==11.0.2.54
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 12.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /srv/conda/envs/notebook/lib/python3.10/site-packages (from torch) (3.12.4)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from torch) (3.1.2)
# Collecting nvidia-cusparse-cu12==12.1.0.106
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==8.9.2.26
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12
#   Downloading nvidia_nvjitlink_cu12-12.3.52-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 42.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.10/site-packages (from gpytorch) (1.1.3)
# Collecting linear-operator>=0.5.0
#   Downloading linear_operator-0.5.2-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.6/175.6 kB 4.5 MB/s eta 0:00:0000:01
# Collecting jaxtyping>=0.2.9
#   Downloading jaxtyping-0.2.23-py3-none-any.whl (29 kB)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from linear-operator>=0.5.0->gpytorch) (1.9.3)
# Collecting typeguard~=2.13.3
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn->gpytorch) (3.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn->gpytorch) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn->gpytorch) (1.23.5)
# Requirement already satisfied: mpmath>=0.19 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: typeguard, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxtyping, nvidia-cusolver-cu12, torch, linear-operator, gpytorch
# Successfully installed gpytorch-1.11 jaxtyping-0.2.23 linear-operator-0.5.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.52 nvidia-nvtx-cu12-12.1.105 torch-2.1.0 triton-2.1.0 typeguard-2.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import gpytorch
import xarray as xr
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
import torch
import math

# %%
# Open the dataset
baker_url = 's3://petrichor/geosmart/baker.zarr/'
baker_ds = xr.open_dataset(
    baker_url, chunks='auto', engine='zarr', storage_options={"anon": True}
)

# %%
baker_ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 55, y: 12089, x: 11383)
# Coordinates:
#   * time         (time) datetime64[ns] 1947-09-14 1950-09-02 ... 2020-12-12
#   * x            (x) float64 5.809e+05 5.809e+05 ... 5.923e+05 5.923e+05
#   * y            (y) float64 5.409e+06 5.409e+06 ... 5.397e+06 5.397e+06
# Data variables:
#     band1        (time, y, x) float32 dask.array<chunksize=(55, 712, 670), meta=np.ndarray>
#     spatial_ref  int64 ...
# Attributes:
#     AREA_OR_POINT:  Area
#     add_offset:     0.0
#     crs:            PROJCS["WGS 84 / UTM zone 10N",GEOGCS["WGS 84",DATUM["WGS...
#     scale_factor:   1.0

# %%
import xarray as xr
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

class XarrayRayChunkedDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.chunk_coords = self._get_chunk_coordinates(data)
        
    def _get_chunk_coordinates(self, data):
        coords = []
        chunk_info = dict(data.chunks)
        for i in range(len(chunk_info["x"])):
            for j in range(len(chunk_info["y"])):
                for k in range(len(chunk_info["time"])):
                    x_start = sum(chunk_info["x"][:i])
                    x_chunk = chunk_info["x"][i]
                    
                    y_start = sum(chunk_info["y"][:j])
                    y_chunk = chunk_info["y"][j]
                    
                    t_start = sum(chunk_info["time"][:k])
                    t_chunk = chunk_info["time"][k]
                    
                    coords.append({'x': slice(x_start, x_start + x_chunk), 
                                   'y': slice(y_start, y_start + y_chunk), 
                                   'time': slice(t_start, t_start + t_chunk)})
        return coords
    
    def __len__(self):
        return len(self.chunk_coords)
    
    def __getitem__(self, idx):
        # TODO convert to a torch.Tensor of shape (N, 4)
        return self.data.isel(self.chunk_coords[idx])
    
dataset = XarrayRayChunkedDataset(baker_ds)
# chunk = dataset[0]

# %%
len(dataset)
# Out:
# 289

# %%
dataset[0]
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 55, y: 712, x: 670)
# Coordinates:
#   * time         (time) datetime64[ns] 1947-09-14 1950-09-02 ... 2020-12-12
#   * x            (x) float64 5.809e+05 5.809e+05 ... 5.816e+05 5.816e+05
#   * y            (y) float64 5.409e+06 5.409e+06 ... 5.409e+06 5.409e+06
# Data variables:
#     band1        (time, y, x) float32 dask.array<chunksize=(55, 712, 670), meta=np.ndarray>
#     spatial_ref  int64 ...
# Attributes:
#     AREA_OR_POINT:  Area
#     add_offset:     0.0
#     crs:            PROJCS["WGS 84 / UTM zone 10N",GEOGCS["WGS 84",DATUM["WGS...
#     scale_factor:   1.0

# %%
chunk
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 55, y: 712, x: 670)
# Coordinates:
#   * time         (time) datetime64[ns] 1947-09-14 1950-09-02 ... 2020-12-12
#   * x            (x) float64 5.809e+05 5.809e+05 ... 5.816e+05 5.816e+05
#   * y            (y) float64 5.409e+06 5.409e+06 ... 5.409e+06 5.409e+06
# Data variables:
#     band1        (time, y, x) float32 dask.array<chunksize=(55, 712, 670), meta=np.ndarray>
#     spatial_ref  int64 ...
# Attributes:
#     AREA_OR_POINT:  Area
#     add_offset:     0.0
#     crs:            PROJCS["WGS 84 / UTM zone 10N",GEOGCS["WGS 84",DATUM["WGS...
#     scale_factor:   1.0

# %%
chunk.band1.to_dataframe().count()
# Out:
# band1    16100086
# dtype: int64

# %%
chunk.band1.to_dataframe()
# Out:
#                                              band1
# time       y            x
# 1947-09-14 5.409449e+06 580947.438712   706.601624
#                         580948.438712   707.278198
#                         580949.438712   707.780396
#                         580950.438712   708.258789
#                         580951.438712   708.737122
# ...                                            ...
# 2020-12-12 5.408738e+06 581612.438712  1150.199341
#                         581613.438712  1150.684570
#                         581614.438712  1151.139526
#                         581615.438712  1151.559814
#                         581616.438712  1151.921021
#
# [26237200 rows x 1 columns]

# %%
df = chunk.band1.to_dataframe()
dfna = df[df.isna().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 df = chunk.band1.to_dataframe(sparse=True)
#       2 dfna = df[df.isna().any(axis=1)]
#
# TypeError: DataArray.to_dataframe() got an unexpected keyword argument 'sparse'

# %%
dfna
# Out:
#                                        band1
# time       y            x
# 1947-09-14 5.409449e+06 580973.438712    NaN
#                         580974.438712    NaN
#                         580975.438712    NaN
#                         580976.438712    NaN
#                         580977.438712    NaN
# ...                                      ...
# 2020-09-05 5.408738e+06 581612.438712    NaN
#                         581613.438712    NaN
#                         581614.438712    NaN
#                         581615.438712    NaN
#                         581616.438712    NaN
#
# [10137114 rows x 1 columns]

# %% [markdown]
# ### Transform chunk to a tensor

# %%
df = chunk.band1.to_dataframe().dropna().reset_index()
df.head()
# Out:
#         time             y              x       band1
# 0 1947-09-14  5.409449e+06  580947.438712  706.601624
# 1 1947-09-14  5.409449e+06  580948.438712  707.278198
# 2 1947-09-14  5.409449e+06  580949.438712  707.780396
# 3 1947-09-14  5.409449e+06  580950.438712  708.258789
# 4 1947-09-14  5.409449e+06  580951.438712  708.737122

# %%
# Cast times to a number
df['time'] = (df['time'] - df['time'].min())  / np.timedelta64(1,'D')

# %%
# Make the X and Y tensors
df_numpy = df.to_numpy(dtype=np.float64)
df_numpy.shape

X = torch.from_numpy(df_numpy[:,:-1]).double()
Y = torch.from_numpy(df_numpy[:,-1]).double()

print(X.shape, Y.shape)
# Out:
# torch.Size([16100086, 3]) torch.Size([16100086])

# %% [markdown]
# ### Train model with the tensor
#
# Copied from [here](https://docs.gpytorch.ai/en/stable/examples/01_Exact_GPs/Simple_GP_Regression.html)

# %%
# Allocates too much memory with full chunk, try again with a smaller size
X_small = X[:10000, :]
Y_small = Y[:10000]

class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(X_small, Y_small, likelihood)

# %%
# Find optimal model hyperparameters
model.train()
likelihood.train()
# Out:
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 50

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(X_small)
    # Calc loss and backprop gradients
    loss = -mll(output, Y_small)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/50 - Loss: 125294.163   lengthscale: 0.693   noise: 0.693
# Iter 2/50 - Loss: 105217.480   lengthscale: 0.744   noise: 0.744
# Iter 3/50 - Loss: 88579.354   lengthscale: 0.798   noise: 0.797
# Iter 4/50 - Loss: 74870.433   lengthscale: 0.853   noise: 0.851
# Iter 5/50 - Loss: 63611.676   lengthscale: 0.909   noise: 0.904
# Iter 6/50 - Loss: 54376.231   lengthscale: 0.966   noise: 0.957
# Iter 7/50 - Loss: 46796.652   lengthscale: 1.024   noise: 1.009
# Iter 8/50 - Loss: 40564.113   lengthscale: 1.081   noise: 1.059
# Iter 9/50 - Loss: 35423.532   lengthscale: 1.139   noise: 1.108
# Iter 10/50 - Loss: 31166.808   lengthscale: 1.195   noise: 1.155
# Iter 11/50 - Loss: 27625.628   lengthscale: 1.251   noise: 1.199
# Iter 12/50 - Loss: 24664.645   lengthscale: 1.306   noise: 1.241
# Iter 13/50 - Loss: 22175.364   lengthscale: 1.359   noise: 1.281
# Iter 14/50 - Loss: 20070.925   lengthscale: 1.411   noise: 1.319
# Iter 15/50 - Loss: 18281.764   lengthscale: 1.461   noise: 1.355
# Iter 16/50 - Loss: 16752.076   lengthscale: 1.510   noise: 1.388
# Iter 17/50 - Loss: 15436.983   lengthscale: 1.557   noise: 1.420
# Iter 18/50 - Loss: 14300.255   lengthscale: 1.602   noise: 1.450
# Iter 19/50 - Loss: 13312.551   lengthscale: 1.645   noise: 1.477
# Iter 20/50 - Loss: 12449.986   lengthscale: 1.687   noise: 1.503
# Iter 21/50 - Loss: 11693.045   lengthscale: 1.727   noise: 1.528
# Iter 22/50 - Loss: 11025.691   lengthscale: 1.765   noise: 1.551
# Iter 23/50 - Loss: 10434.692   lengthscale: 1.801   noise: 1.572
# Iter 24/50 - Loss: 9909.069   lengthscale: 1.837   noise: 1.592
# Iter 25/50 - Loss: 9439.676   lengthscale: 1.870   noise: 1.611
# Iter 26/50 - Loss: 9018.853   lengthscale: 1.902   noise: 1.628
# Iter 27/50 - Loss: 8640.168   lengthscale: 1.933   noise: 1.645
# Iter 28/50 - Loss: 8298.166   lengthscale: 1.962   noise: 1.660
# Iter 29/50 - Loss: 7988.222   lengthscale: 1.990   noise: 1.674
# Iter 30/50 - Loss: 7706.410   lengthscale: 2.017   noise: 1.688
# Iter 31/50 - Loss: 7449.355   lengthscale: 2.043   noise: 1.700
# Iter 32/50 - Loss: 7214.153   lengthscale: 2.067   noise: 1.712
# Iter 33/50 - Loss: 6998.315   lengthscale: 2.091   noise: 1.723
# Iter 34/50 - Loss: 6799.677   lengthscale: 2.113   noise: 1.734
# Iter 35/50 - Loss: 6616.356   lengthscale: 2.135   noise: 1.743
# Iter 36/50 - Loss: 6446.728   lengthscale: 2.156   noise: 1.753
# Iter 37/50 - Loss: 6289.339   lengthscale: 2.176   noise: 1.761
# Iter 38/50 - Loss: 6142.957   lengthscale: 2.195   noise: 1.769
# Iter 39/50 - Loss: 6006.468   lengthscale: 2.213   noise: 1.777
# Iter 40/50 - Loss: 5878.905   lengthscale: 2.231   noise: 1.784
# Iter 41/50 - Loss: 5759.405   lengthscale: 2.248   noise: 1.791
# Iter 42/50 - Loss: 5647.204   lengthscale: 2.265   noise: 1.797
# Iter 43/50 - Loss: 5541.633   lengthscale: 2.281   noise: 1.803
# Iter 44/50 - Loss: 5442.086   lengthscale: 2.296   noise: 1.809
# Iter 45/50 - Loss: 5348.022   lengthscale: 2.311   noise: 1.815
# Iter 46/50 - Loss: 5258.966   lengthscale: 2.326   noise: 1.820
# Iter 47/50 - Loss: 5174.485   lengthscale: 2.340   noise: 1.825
# Iter 48/50 - Loss: 5094.205   lengthscale: 2.353   noise: 1.830
# Iter 49/50 - Loss: 5017.763   lengthscale: 2.367   noise: 1.834
# Iter 50/50 - Loss: 4944.852   lengthscale: 2.380   noise: 1.838

# %%
# Below does not work because of a type mismatch - not sure why :(

# Visualize output

# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
#with torch.no_grad(), gpytorch.settings.fast_pred_var():
#    observed_pred = likelihood(model(X_small))
